# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("./data2/개인_이러닝_이용률_및_이용방법_20230608122439.xlsx",index_col=0)

# %%
df
# Out:
#             특성별(2)  2011 2011.1   2011.2         2011.3              2011.4  \
# 특성별(1)
# 특성별(1)      특성별(2)   이용률    이용률     이용방법           이용방법                이용방법
# 특성별(1)      특성별(2)     예    아니오  교육방송 시청  인터넷 전문교육 제공강의  교재 CD 및 인터넷 강좌용 CD
# 전체              소계  52.8   47.2     60.5           35.7                21.5
# 성별              남자  53.1   46.9     56.6           37.2                22.6
# NaN             여자  52.5   47.5     64.9             34                20.3
# 연령별           3~7세  38.5   61.5     91.8            4.7                12.9
# NaN           3~9세     -      -        -              -                   -
# NaN          8~19세  74.5   25.5     81.1           18.6                11.3
# NaN         20~29세  67.9   32.1     51.3           41.5                33.3
# NaN         30~39세  44.9   55.1     39.8           48.7                23.4
# NaN         40~49세  41.6   58.4     54.7           49.7                23.1
# ...

# %%
df.loc["전체","2011"]
# Out:
# 52.8

# %%
using = []
year = []
year.append("특성별(2)")
for i in range(2011,2021):
    a = df.loc["전체",str(i)]
    year.append(str(i))
    using.append(a)

# %%
using
# Out:
# [52.8, 53.3, 57.1, 57.6, 58.2, 58.7, 58.9, 59, 59.2, 62.5]

# %%
df_1 = df[year]

# %%
df_1.set_index("특성별(2)",drop=True,inplace=True)

# %%
df_1
# Out:
#             2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 특성별(2)
# 특성별(2)       이용률   이용률   이용률   이용률   이용률   이용률   이용률   이용률   이용률   이용률
# 특성별(2)         예     예     예     예     예     예     예     예     예     예
# 소계          52.8  53.3  57.1  57.6  58.2  58.7  58.9    59  59.2  62.5
# 남자          53.1    54  57.9  58.4  58.8  59.4  59.3  59.6  59.9  63.9
# 여자          52.5  52.6  56.3  56.8  57.5  57.9  58.3  58.4  58.6  61.1
# 3~7세        38.5  43.2  44.3  46.1     -     -     -     -     -     -
# 3~9세           -     -     -     -  46.4  47.6  51.1  51.1  51.5  53.5
# 8~19세       74.5  79.7  80.2  80.6     -     -     -     -     -     -
# 20~29세      67.9  71.7  73.4  74.6     -     -     -     -     -     -
# 30~39세      44.9  49.6  54.8  56.5     -     -     -     -     -     -
# 40~49세      41.6  42.3  47.5  48.4     -     -     -     -     -     -
# 10대            -     -     -     -  80.8  81.7  83.5  83.5  83.7  89.7
# ...

# %%
df_1.drop('특성별(2)',inplace=True)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_3512\90340101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_1.drop('특성별(2)',inplace=True)

# %%
df_1.index.names = ['분류']

# %%
df_1
# Out:
#             2011  2012  2013  2014  2015  2016  2017  2018  2019  2020
# 분류
# 소계          52.8  53.3  57.1  57.6  58.2  58.7  58.9    59  59.2  62.5
# 남자          53.1    54  57.9  58.4  58.8  59.4  59.3  59.6  59.9  63.9
# 여자          52.5  52.6  56.3  56.8  57.5  57.9  58.3  58.4  58.6  61.1
# 3~7세        38.5  43.2  44.3  46.1     -     -     -     -     -     -
# 3~9세           -     -     -     -  46.4  47.6  51.1  51.1  51.5  53.5
# 8~19세       74.5  79.7  80.2  80.6     -     -     -     -     -     -
# 20~29세      67.9  71.7  73.4  74.6     -     -     -     -     -     -
# 30~39세      44.9  49.6  54.8  56.5     -     -     -     -     -     -
# 40~49세      41.6  42.3  47.5  48.4     -     -     -     -     -     -
# 10대            -     -     -     -  80.8  81.7  83.5  83.5  83.7  89.7
# 20대            -     -     -     -  76.2  76.3    77  77.1  77.2  82.5
# 30대            -     -     -     -  58.8  58.9  59.3  59.5  59.6  62.8
# ...

# %%
df_3 = pd.read_excel("./data2/이러닝_수요시장_규모_추이_20230612162819.xlsx")
df_4 = pd.read_excel("./data2/이러닝_수요시장_규모_추이_20230612163008.xlsx")
# Out:
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df_3
# Out:
#   조직형태별(1)     2016     2017     2018     2019     2020
# 0       전체  3428665  3629870  3777241  3860943  4568109
# 1       개인  1581560  1668192  1784824  1813261  2365791
# 2      사업체  1451360  1513983  1535444  1569416  1658085
# 3   정규교육기관   171798   199500   205624   222647   269666
# 4  정부/공공기관   223947   248195   251349   255619   274567

# %%
df_4 = df_4.drop(0)
df_4 = df_4.drop("2021.1",axis=1)

# %%
df_4 = df_4.drop("2021.2",axis=1)
df_4
# Out:
#   조직형태별(1)     2021
# 1       전체  5039933
# 2       개인  2607875
# 3      사업체  1806701
# 4   정규교육기관   309263
# 5  정부/공공기관   316094

# %%
df_4.reset_index(drop=True,inplace=True)

# %%
a = pd.concat([df_3,df_4])

a
# Out:
#   조직형태별(1)       2016       2017       2018       2019       2020     2021
# 0       전체  3428665.0  3629870.0  3777241.0  3860943.0  4568109.0      NaN
# 1       개인  1581560.0  1668192.0  1784824.0  1813261.0  2365791.0      NaN
# 2      사업체  1451360.0  1513983.0  1535444.0  1569416.0  1658085.0      NaN
# 3   정규교육기관   171798.0   199500.0   205624.0   222647.0   269666.0      NaN
# 4  정부/공공기관   223947.0   248195.0   251349.0   255619.0   274567.0      NaN
# 0       전체        NaN        NaN        NaN        NaN        NaN  5039933
# 1       개인        NaN        NaN        NaN        NaN        NaN  2607875
# 2      사업체        NaN        NaN        NaN        NaN        NaN  1806701
# 3   정규교육기관        NaN        NaN        NaN        NaN        NaN   309263
# 4  정부/공공기관        NaN        NaN        NaN        NaN        NaN   316094

# %%
df_3["2021"] = df_4["2021"]

# %%
df_3.set_index("조직형태별(1)",inplace=True)
df_3.index_name = ["구분"]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_3512\2893649828.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df_3.index_name = ["구분"]

# %%
df = df_3.T
df
# Out:
# 조직형태별(1)       전체       개인      사업체  정규교육기관 정부/공공기관
# 2016      3428665  1581560  1451360  171798  223947
# 2017      3629870  1668192  1513983  199500  248195
# 2018      3777241  1784824  1535444  205624  251349
# 2019      3860943  1813261  1569416  222647  255619
# 2020      4568109  2365791  1658085  269666  274567
# 2021      5039933  2607875  1806701  309263  316094

# %%
df.columns.name ='구분'

# %%
df = df/100000

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Malgun Gothic'
plt.rcParams['axes.unicode_minus'] = False

plt.figure(figsize=(10,8),facecolor='seashell')
plt.grid(True, axis='x')
ax = plt.gca()
ax.set_facecolor('seashell')
ax.patch.set_alpha(0.9)
plt.title('background color is violet')


plt.plot(df.index,df["전체"], marker='o')
plt.plot(df.index,df["개인"],marker='o')
plt.plot(df.index,df["사업체"],marker='o')
plt.plot(df.index,df["정규교육기관"],marker='o')
plt.plot(df.index,df["정부/공공기관"],marker='o')
plt.xlabel('년도', labelpad=15)
plt.ylabel('수요금액(조)', labelpad=20)
plt.title('이러닝 산업 수요시장 규모')

plt.legend(df.columns)
plt.show()

# %%
df_3.T
# Out:
# 구분         전체       개인      사업체  정규교육기관 정부/공공기관
# 2016  3428665  1581560  1451360  171798  223947
# 2017  3629870  1668192  1513983  199500  248195
# 2018  3777241  1784824  1535444  205624  251349
# 2019  3860943  1813261  1569416  222647  255619
# 2020  4568109  2365791  1658085  269666  274567
# 2021  5039933  2607875  1806701  309263  316094
