# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_excel("./data/Ashopping.xlsx")
df1
# Out:
#      고객ID  이탈여부     총_매출액  방문빈도  1회_평균매출액  할인권_사용 횟수  총_할인_금액  고객등급  구매유형  \
# 0       1     0   4007080    17    235711          1     5445     1     4
# 1       2     1   3168400    14    226314         22   350995     2     4
# 2       3     0   2680780    18    148932          6   186045     1     4
# 3       4     0   5946600    17    349800          1     5195     1     4
# 4       5     0  13745950    73    188301          9   246350     1     2
# ..    ...   ...       ...   ...       ...        ...      ...   ...   ...
# 995   996     0   5135090     8    641886          3    44445     1     3
# 996   997     0  10315690    49    210524          6   186545     1     2
# 997   998     0   2741290    10    274129          8   260700     2     4
# 998   999     0  11268990    15    751266         20   347700     1     3
# 999  1000     0   3182880    23    138386         19   367045     1     4
#
#      클레임접수여부  ...  매장_청결성  공간_편의성  시야_확보성  음향_적절성  안내_표지판_설명  친절성  신속성  책임성  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   고객ID              1000 non-null   int64
#  1   이탈여부              1000 non-null   int64
#  2   총_매출액             1000 non-null   int64
#  3   방문빈도              1000 non-null   int64
#  4   1회_평균매출액          1000 non-null   int64
#  5   할인권_사용 횟수         1000 non-null   int64
#  6   총_할인_금액           1000 non-null   int64
#  7   고객등급              1000 non-null   int64
#  8   구매유형              1000 non-null   int64
#  9   클레임접수여부           1000 non-null   int64
#  10  구매_카테고리_수         1000 non-null   int64
#  11  거주지역              1000 non-null   int64
#  12  성별                1000 non-null   int64
#  13  고객_나이대            1000 non-null   int64
#  14  거래기간              1000 non-null   int64
#  15  할인민감여부            1000 non-null   int64
# ...

# %%
df2 = pd.read_excel("./data/online_diet.xlsx")
df2
# Out:
# c:\Users\OPERATOR-70\anaconda3\lib\site-packages\openpyxl\worksheet\header_footer.py:48: UserWarning: Cannot parse header or footer so it will be ignored
#   warn("""Cannot parse header or footer so it will be ignored""")
#       seq_num          id  social_id1 zip_code  occupation  sex  height  \
# 0          28    webinner    740101.0  137-070         6.0  1.0   170.0
# 1          29    webinner    740101.0  137-070         6.0  1.0   170.0
# 2          30    webinner    740101.0  137-070         6.0  1.0   170.0
# 3          31    webinner    740101.0  137-070         6.0  1.0   170.0
# 4          32    webinner    740101.0  137-070         6.0  1.0   170.0
# ...       ...         ...         ...      ...         ...  ...     ...
# 4453     2011  0162655575    830219.0  135-080        15.0  2.0   165.0
# 4454     2012      12girl    781007.0  136-043        17.0  2.0   160.0
# 4455     2013  onlyonelhm    880330.0  327-030        15.0  2.0   159.0
# ...

# %%
df2.isnull().sum()
# Out:
# seq_num            0
# id                 0
# social_id1         1
# zip_code           2
# occupation         2
# sex                2
# height             2
# weight             2
# married            2
# dise            1528
# want_diet          2
# created            0
# waist           1323
# heap            2559
# loss_part        252
# diet_purpose     275
# diet            1047
# bmi                2
# order_id           0
# pfid               0
# p_name             0
# p_price            0
# p_created          0
# p_quantity         0
# dtype: int64

# %%
for i in df2.index:
    if df2.loc[i,"loss_part"].str.contains('1',na=False)== 1:
        df2.loc[i,'1'] = 1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\OPERATOR-70\Desktop\튜터링\튜터링\1기(마케팅) 튜터링\빅분기연습\practice.ipynb Cell 7 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/OPERATOR-70/Desktop/%ED%8A%9C%ED%84%B0%EB%A7%81/%ED%8A%9C%ED%84%B0%EB%A7%81/1%EA%B8%B0%28%EB%A7%88%EC%BC%80%ED%8C%85%29%20%ED%8A%9C%ED%84%B0%EB%A7%81/%EB%B9%85%EB%B6%84%EA%B8%B0%EC%97%B0%EC%8A%B5/practice.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> for i in df2.index:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OPERATOR-70/Desktop/%ED%8A%9C%ED%84%B0%EB%A7%81/%ED%8A%9C%ED%84%B0%EB%A7%81/1%EA%B8%B0%28%EB%A7%88%EC%BC%80%ED%8C%85%29%20%ED%8A%9C%ED%84%B0%EB%A7%81/%EB%B9%85%EB%B6%84%EA%B8%B0%EC%97%B0%EC%8A%B5/practice.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a>     if df2.loc[i,"loss_part"].str.contains('1',na=False)== 1:
# ...

# %%
(df2["loss_part"].str.contains('1',na=False)== 1)* 1
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4453    0
# 4454    1
# 4455    1
# 4456    1
# 4457    1
# Name: loss_part, Length: 4458, dtype: int32

# %%
df2["1"] = (df2["loss_part"].str.contains('1',na=False)* 1)
df2["2"] = (df2["loss_part"].str.contains('2',na=False)* 2)
df2["3"] = (df2["loss_part"].str.contains('3',na=False)* 3)
df2
# Out:
#       seq_num          id  social_id1 zip_code  occupation  sex  height  \
# 0          28    webinner    740101.0  137-070         6.0  1.0   170.0
# 1          29    webinner    740101.0  137-070         6.0  1.0   170.0
# 2          30    webinner    740101.0  137-070         6.0  1.0   170.0
# 3          31    webinner    740101.0  137-070         6.0  1.0   170.0
# 4          32    webinner    740101.0  137-070         6.0  1.0   170.0
# ...       ...         ...         ...      ...         ...  ...     ...
# 4453     2011  0162655575    830219.0  135-080        15.0  2.0   165.0
# 4454     2012      12girl    781007.0  136-043        17.0  2.0   160.0
# 4455     2013  onlyonelhm    880330.0  327-030        15.0  2.0   159.0
# 4456     2014   morebest1    760709.0  0000000        12.0  1.0   177.0
# 4457     2015      kiya80    770426.0  660-322        12.0  2.0   156.0
#
#       weight  married dise  ...   bmi order_id        pfid  \
# ...

# %%
list = ["1","2","3","4","5","6","7"]
# Out:
#       seq_num          id  social_id1 zip_code  occupation  sex  height  \
# 0          28    webinner    740101.0  137-070         6.0  1.0   170.0
# 1          29    webinner    740101.0  137-070         6.0  1.0   170.0
# 2          30    webinner    740101.0  137-070         6.0  1.0   170.0
# 3          31    webinner    740101.0  137-070         6.0  1.0   170.0
# 4          32    webinner    740101.0  137-070         6.0  1.0   170.0
# ...       ...         ...         ...      ...         ...  ...     ...
# 4453     2011  0162655575    830219.0  135-080        15.0  2.0   165.0
# 4454     2012      12girl    781007.0  136-043        17.0  2.0   160.0
# 4455     2013  onlyonelhm    880330.0  327-030        15.0  2.0   159.0
# 4456     2014   morebest1    760709.0  0000000        12.0  1.0   177.0
# 4457     2015      kiya80    770426.0  660-322        12.0  2.0   156.0
#
#       weight  married dise  ...     diet   bmi order_id        pfid  \
# ...

# %%
df2["id"].value_counts()
# Out:
# webinner      64
# ivy0222       31
# rosareo       16
# gooddiet      14
# youngya624    11
#               ..
# donggle6       1
# sunhi6         1
# sae011         1
# jjh990662      1
# kiya80         1
# Name: id, Length: 3314, dtype: int64

# %%
a = df2[df2["id"] == 'webinner']
a
# Out:
#       seq_num        id  social_id1 zip_code  occupation  sex  height  weight  \
# 0          28  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 1          29  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 2          30  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 3          31  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 4          32  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# ...       ...       ...         ...      ...         ...  ...     ...     ...
# 3361      811  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 3746     1225  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 3818     1303  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 4207     1744  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 4350     1893  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
#
# ...

# %%
b = a[:30]
c = a[30:]

# %%
d = pd.merge(b,c,how='outer')
d
# Out:
# C:\Users\OPERATOR-70\AppData\Local\Temp\ipykernel_24892\2404575283.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   d = pd.merge(b,c,how='outer')
#     seq_num        id  social_id1 zip_code  occupation  sex  height  weight  \
# 0        28  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 1        29  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 2        30  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 3        31  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 4        32  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# ..      ...       ...         ...      ...         ...  ...     ...     ...
# 59      811  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# 60     1225  webinner    740101.0  137-070         6.0  1.0   170.0    62.0
# ...

# %%
e = pd.merge(b,c,how='inner')
e
# Out:
# Empty DataFrame
# Columns: [seq_num, id, social_id1, zip_code, occupation, sex, height, weight, married, dise, want_diet, created, waist, heap, loss_part, diet_purpose, diet, bmi, order_id, pfid, p_name, p_price, p_created, p_quantity]
# Index: []
#
# [0 rows x 24 columns]

# %%
e = pd.merge(b,c, how ='inner',on='id')
e
# Out:
#       seq_num_x        id  social_id1_x zip_code_x  occupation_x  sex_x  \
# 0            28  webinner      740101.0    137-070           6.0    1.0
# 1            28  webinner      740101.0    137-070           6.0    1.0
# 2            28  webinner      740101.0    137-070           6.0    1.0
# 3            28  webinner      740101.0    137-070           6.0    1.0
# 4            28  webinner      740101.0    137-070           6.0    1.0
# ...         ...       ...           ...        ...           ...    ...
# 1015       3212  webinner      740101.0    137-070           6.0    1.0
# 1016       3212  webinner      740101.0    137-070           6.0    1.0
# 1017       3212  webinner      740101.0    137-070           6.0    1.0
# 1018       3212  webinner      740101.0    137-070           6.0    1.0
# 1019       3212  webinner      740101.0    137-070           6.0    1.0
#
#       height_x  weight_x  married_x dise_x  ...  loss_part_y diet_purpose_y  \
# ...

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64 entries, 0 to 63
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   seq_num       64 non-null     int64
#  1   id            64 non-null     object
#  2   social_id1    64 non-null     float64
#  3   zip_code      64 non-null     object
#  4   occupation    64 non-null     float64
#  5   sex           64 non-null     float64
#  6   height        64 non-null     float64
#  7   weight        64 non-null     float64
#  8   married       64 non-null     float64
#  9   dise          0 non-null      object
#  10  want_diet     64 non-null     float64
#  11  created       64 non-null     object
#  12  waist         0 non-null      object
#  13  heap          0 non-null      object
#  14  loss_part     64 non-null     object
#  15  diet_purpose  64 non-null     float64
#  16  diet          64 non-null     object
#  17  bmi           64 non-null     float64
# ...

# %%
b = df2[(df2["id"] == 'ivy0222') | (df2["id"] == 'youngya624')]
b
# Out:
#       seq_num          id  social_id1 zip_code  occupation  sex  height  \
# 262      4366  youngya624    570524.0  791-758        14.0  2.0   152.0
# 263      4367  youngya624    570524.0  791-758        14.0  2.0   152.0
# 264      4368  youngya624    570524.0  791-758        14.0  2.0   152.0
# 282      4387     ivy0222    830222.0  000-000        15.0  2.0   164.0
# 283      4388     ivy0222    830222.0  000-000        15.0  2.0   164.0
# 284      4389     ivy0222    830222.0  000-000        15.0  2.0   164.0
# 285      4390     ivy0222    830222.0  000-000        15.0  2.0   164.0
# 293      4398  youngya624    570524.0  791-758        14.0  2.0   152.0
# 489      4278  youngya624    570524.0  791-758        14.0  2.0   152.0
# 490      4279  youngya624    570524.0  791-758        14.0  2.0   152.0
# 491      4280  youngya624    570524.0  791-758        14.0  2.0   152.0
# 492      4281  youngya624    570524.0  791-758        14.0  2.0   152.0
# ...

# %%
df = pd.merge(a,b, on='')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\OPERATOR-70\Desktop\튜터링\튜터링\1기(마케팅) 튜터링\빅분기연습\practice.ipynb Cell 13 in 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/OPERATOR-70/Desktop/%ED%8A%9C%ED%84%B0%EB%A7%81/%ED%8A%9C%ED%84%B0%EB%A7%81/1%EA%B8%B0%28%EB%A7%88%EC%BC%80%ED%8C%85%29%20%ED%8A%9C%ED%84%B0%EB%A7%81/%EB%B9%85%EB%B6%84%EA%B8%B0%EC%97%B0%EC%8A%B5/practice.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> df = pd.merge(a,b, on='')
#
# File c:\Users\OPERATOR-70\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:110, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      93 @Substitution("\nleft : DataFrame or named Series")
#      94 @Appender(_merge_doc, indents=0)
#      95 def merge(
#    (...)
#     108     validate: str | None = None,
#     109 ) -> DataFrame:
# ...

# %%
df
# Out:
# Empty DataFrame
# Columns: [seq_num, id, social_id1, zip_code, occupation, sex, height, weight, married, dise, want_diet, created, waist, heap, loss_part, diet_purpose, diet, bmi, order_id, pfid, p_name, p_price, p_created, p_quantity]
# Index: []
#
# [0 rows x 24 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4458 entries, 0 to 4457
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   seq_num       4458 non-null   int64
#  1   id            4458 non-null   object
#  2   social_id1    4457 non-null   float64
#  3   zip_code      4456 non-null   object
#  4   occupation    4456 non-null   float64
#  5   sex           4456 non-null   float64
#  6   height        4456 non-null   float64
#  7   weight        4456 non-null   float64
#  8   married       4456 non-null   float64
#  9   dise          2930 non-null   object
#  10  want_diet     4456 non-null   float64
#  11  created       4458 non-null   object
#  12  waist         3135 non-null   object
#  13  heap          1899 non-null   object
#  14  loss_part     4206 non-null   object
#  15  diet_purpose  4183 non-null   float64
#  16  diet          3411 non-null   object
#  17  bmi           4456 non-null   float64
# ...

# %%
# 결측치 여부 확인하기
df1.isnull().sum()
# Out:
# 고객ID                  0
# 이탈여부                  0
# 총_매출액                 0
# 방문빈도                  0
# 1회_평균매출액              0
# 할인권_사용 횟수             0
# 총_할인_금액               0
# 고객등급                  0
# 구매유형                  0
# 클레임접수여부               0
# 구매_카테고리_수             0
# 거주지역                  0
# 성별                    0
# 고객_나이대                0
# 거래기간                  0
# 할인민감여부                0
# 멤버쉽_프로그램_가입전_만족도      0
# 멤버쉽_프로그램_가입후_만족도      0
# Recency               0
# Frequency             0
# Monetary              0
# 상품_만족도                0
# 매장_만족도                0
# 서비스_만족도               0
# 상품_품질                 0
# 상품_다양성                0
# 가격_적절성                0
# 상품_진열_위치             66
# 상품_설명_표시            138
# 매장_청결성                0
# 공간_편의성                0
# 시야_확보성                0
# 음향_적절성                0
# 안내_표지판_설명             0
# 친절성                   0
# 신속성                   0
# 책임성                   0
# 정확성                   0
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4458 entries, 0 to 4457
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   seq_num       4458 non-null   int64
#  1   id            4458 non-null   object
#  2   social_id1    4457 non-null   float64
#  3   zip_code      4456 non-null   object
#  4   occupation    4456 non-null   float64
#  5   sex           4456 non-null   float64
#  6   height        4456 non-null   float64
#  7   weight        4456 non-null   float64
#  8   married       4456 non-null   float64
#  9   dise          2930 non-null   object
#  10  want_diet     4456 non-null   float64
#  11  created       4458 non-null   object
#  12  waist         3135 non-null   object
#  13  heap          1899 non-null   object
#  14  loss_part     4206 non-null   object
#  15  diet_purpose  4183 non-null   float64
#  16  diet          3411 non-null   object
#  17  bmi           4456 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()

# %%
encoder.fit(df2["loss_part"])
# Out:
# LabelEncoder()

# %%
df2["loss_part_2"] = encoder.transform(df2["loss_part"])

# %%
len(df2["loss_part"].unique())
# Out:
# 296

# %%
df2["loss_part_2"]
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#        ...
# 4453    251
# 4454    174
# 4455     17
# 4456     68
# 4457    174
# Name: loss_part_2, Length: 4458, dtype: int32

# %%
df2['result'] = df2['result'] + "," +df2 ['waist']

# %%
df2['waist']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 4453    NaN
# 4454    NaN
# 4455     29
# 4456     40
# 4457     27
# Name: waist, Length: 4458, dtype: object

# %%
df2
# Out:
#       seq_num          id  social_id1 zip_code  occupation  sex  height  \
# 0          28    webinner    740101.0  137-070         6.0  1.0   170.0
# 1          29    webinner    740101.0  137-070         6.0  1.0   170.0
# 2          30    webinner    740101.0  137-070         6.0  1.0   170.0
# 3          31    webinner    740101.0  137-070         6.0  1.0   170.0
# 4          32    webinner    740101.0  137-070         6.0  1.0   170.0
# ...       ...         ...         ...      ...         ...  ...     ...
# 4453     2011  0162655575    830219.0  135-080        15.0  2.0   165.0
# 4454     2012      12girl    781007.0  136-043        17.0  2.0   160.0
# 4455     2013  onlyonelhm    880330.0  327-030        15.0  2.0   159.0
# 4456     2014   morebest1    760709.0  0000000        12.0  1.0   177.0
# 4457     2015      kiya80    770426.0  660-322        12.0  2.0   156.0
#
#       weight  married dise  ...     diet   bmi order_id        pfid  \
# ...

# %%
df2['result']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 4453              NaN
# 4454              NaN
# 4455    onlyonelhm,29
# 4456     morebest1,40
# 4457        kiya80,27
# Name: result, Length: 4458, dtype: object

# %%
for i in df.columns:
    df2['result'] =+ df2[i]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\OPERATOR-70\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py:165, in _na_arithmetic_op(left, right, op, is_cmp)
#     164 try:
# --> 165     result = func(left, right)
#     166 except TypeError:
#
# File c:\Users\OPERATOR-70\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:241, in evaluate(op, a, b, use_numexpr)
#     239     if use_numexpr:
#     240         # error: "None" not callable
# --> 241         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     242 return _evaluate_standard(op, op_str, a, b)
#
# File c:\Users\OPERATOR-70\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:129, in _evaluate_numexpr(op, op_str, a, b)
#     128 if result is None:
# --> 129     result = _evaluate_standard(op, op_str, a, b)
#     131 return result
#
# ...
